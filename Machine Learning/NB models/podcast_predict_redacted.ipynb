# %%
import numpy as np
import pandas as pd

# %%
y_pred = pd.Series(['This American Life', 'This American Life', 'This American Life', 'This American Life', 'This American Life', 'Welcome to Nightvale', 'Welcome to Nightvale', 'Welcome to Nightvale', 'This American Life', 'This American Life', 'This American Life', 'This American Life', 'NeoScum', 'Move Your DNA', 'This American Life', 'This American Life', 'This American Life', 'This American Life', 'This American Life', 'Move Your DNA', 'This American Life', 'This American Life', 'Welcome to Nightvale', 'This American Life', 'This American Life', 'This American Life', 'Move Your DNA', 'Welcome to Nightvale', 'Welcome to Nightvale', 'Welcome to Nightvale', 'This American Life', 'This American Life', 'This American Life', 'This American Life', 'This American Life', 'This American Life', 'Move Your DNA', 'This American Life', 'Welcome to Nightvale', 'Welcome to Nightvale', 'This American Life', 'Friendly Fire', 'This American Life', 'This American Life', 'This American Life', 'Move Your DNA', 'Move Your DNA', 'This American Life', 'Move Your DNA', 'This American Life', 'This American Life', 'This American Life', 'This American Life', 'This American Life', 'This American Life', 'This American Life', 'This American Life', 'Bullseye with Jesse Thorn', 'This American Life', 'Radiolab', 'This American Life', 'This American Life', 'This American Life', 'This American Life', 'This American Life', 'This American Life', 'This American Life', 'This American Life', 'This American Life', 'This American Life', 'This American Life', 'This American Life', 'This American Life', 'Move Your DNA', 'This American Life', 'This American Life', 'Radiolab', 'This American Life', 'This American Life', 'Welcome to Nightvale', 'This American Life', 'This American Life', 'This American Life', 'This American Life', 'Radiolab', 'This American Life', 'This American Life', 'This American Life', 'Radiolab', 'Radiolab', 'This American Life', 'Welcome to Nightvale', 'Welcome to Nightvale', 'This American Life', 'This American Life', 'Move Your DNA', 'This American Life', 'This American Life', 'NeoScum', 'This American Life', 'Radiolab', 'This American Life', 'Move Your DNA', 'Welcome to Nightvale', 'This American Life', 'This American Life', 'This American Life', 'Radiolab', 'This American Life', 'Welcome to Nightvale', 'This American Life', 'Friendly Fire', 'This American Life', 'This American Life', 'This American Life', 'This American Life', 'This American Life', 'The Adventure Zone', 'This American Life', 'This American Life', 'The Greatest Generation', 'This American Life', 'This American Life', 'Radiolab', 'This American Life', 'This American Life', 'This American Life', 'The Greatest Generation', 'This American Life', 'This American Life', 'Bullseye with Jesse Thorn', 'Radiolab', 'Welcome to Nightvale', 'This American Life', 'Radiolab', 'This American Life', 'This American Life', 'This American Life', 'Bullseye with Jesse Thorn', 'This American Life', 'This American Life', 'This American Life', 'Welcome to Nightvale', 'This American Life', 'The Greatest Generation', 'This American Life', 'Welcome to Nightvale', 'This American Life', 'Radiolab', 'This American Life', 'Radiolab', 'This American Life', 'Radiolab', 'Radiolab', 'Friendly Fire', 'This American Life', 'Bullseye with Jesse Thorn', 'Move Your DNA', 'This American Life'], name='Predicted')

# %%
y_test = pd.Series(['This American Life', 'This American Life', 'Wonderful', 'This American Life', 'This American Life', 'Welcome to Nightvale', 'Welcome to Nightvale', 'Welcome to Nightvale', 'Radiolab', 'This American Life', 'Radiolab', 'Radiolab', 'NeoScum', 'Move Your DNA', 'This American Life', 'This American Life', 'The Flophouse', 'Judge John Hodgman', 'MBMBaM', 'Move Your DNA', 'This American Life', 'This American Life', 'Welcome to Nightvale', 'This American Life', 'This American Life', 'This American Life', 'Move Your DNA', 'Welcome to Nightvale', 'Welcome to Nightvale', 'Welcome to Nightvale', 'This American Life', 'This American Life', 'Sawbones', 'This American Life', 'This American Life', 'Unlocking Us', 'Move Your DNA', 'This American Life', 'Welcome to Nightvale', 'Welcome to Nightvale', 'This American Life', 'Friendly Fire', 'Radiolab', 'This American Life', 'This American Life', 'Move Your DNA', 'Move Your DNA', 'This American Life', 'Move Your DNA', 'This American Life', 'MBMBaM', 'This American Life', 'This American Life', 'This American Life', 'Bullseye with Jesse Thorn', 'This American Life', 'One Bad Mother', 'Bullseye with Jesse Thorn', 'The Flophouse', 'Radiolab', 'This American Life', 'This American Life', 'This American Life', 'This American Life', 'This American Life', 'This American Life', 'Judge John Hodgman', 'This American Life', 'This American Life', 'This American Life', 'This American Life', 'Bullseye with Jesse Thorn', 'This American Life', 'Move Your DNA', 'This American Life', 'Shmanners', 'Radiolab', 'This American Life', 'This American Life', 'Welcome to Nightvale', 'This American Life', 'One Bad Mother', 'This American Life', 'This American Life', 'Radiolab', 'This American Life', 'This American Life', 'This American Life', 'Radiolab', 'Radiolab', 'This American Life', 'Welcome to Nightvale', 'Welcome to Nightvale', 'This American Life', 'This American Life', 'Move Your DNA', 'This American Life', 'Shmanners', 'NeoScum', 'Wonderful', 'Radiolab', 'Radiolab', 'Move Your DNA', 'Welcome to Nightvale', 'Judge John Hodgman', 'This American Life', 'One Bad Mother', 'Radiolab', 'This American Life', 'Welcome to Nightvale', 'This American Life', 'Friendly Fire', 'Shmanners', 'This American Life', 'This American Life', 'This American Life', 'This American Life', 'The Adventure Zone', 'This American Life', 'This American Life', 'The Greatest Generation', 'Sawbones', 'This American Life', 'Radiolab', 'This American Life', 'This American Life', 'The Adventure Zone', 'The Greatest Generation', 'This American Life', 'This American Life', 'Bullseye with Jesse Thorn', 'Radiolab', 'Welcome to Nightvale', 'Switchblade Sisters', 'Radiolab', 'This American Life', 'MBMBaM', "You're Wrong About", 'Bullseye with Jesse Thorn', 'This American Life', 'This American Life', 'This American Life', 'Welcome to Nightvale', 'This American Life', 'The Greatest Generation', 'This American Life', 'Welcome to Nightvale', 'Sawbones', 'Radiolab', 'This American Life', 'Radiolab', 'Wonderful', 'Radiolab', 'Radiolab', 'Friendly Fire', 'This American Life', 'Bullseye with Jesse Thorn', 'Move Your DNA', 'This American Life'], name='True')

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# function to show confusion matrix
def plot_cm(y_test, y_pred, model_name, ticks):
    fig, ax = plt.subplots(figsize=(10,10))
    cm = confusion_matrix(y_test, y_pred)
    sns.heatmap(cm, square=True, annot=True, fmt='d', cmap='Blues',
                xticklabels=ticks, yticklabels=ticks, ax=ax)
    plt.xlabel('predicted label')
    plt.ylabel('true label')
    plt.title(f'{model_name} accuracy: {accuracy_score(y_test, y_pred)*100:0.4f}%'.format(model_name, accuracy_score(y_test, y_pred)))
    fig.savefig('../figures/lexical_features/podcast_predict_redacted.pdf')
    plt.show()
    
plot_cm(y_test, y_pred, 'Podcast with redacted text', sorted(set(y_test)))
